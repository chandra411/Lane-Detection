# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive/

# %%
# %cd drive/My\ Drive/Lane_Detection/Lane-Detection
# Out:
# /content/drive/My Drive/Lane_Detection/Lane-Detection

# %%
# !ls
# Out:
# augmentation.py        README.md	 test_images  TfRead.pyc     train.py
# generate_tfrecords.py  requirements.txt  test_out     tf_records
# Lane_Detection	       resnet.py	 test.py      tfrecords_aug
# models		       resnet.pyc	 TfRead.py    train_outs

# %%
# !nvidia-smi
# Out:
# Mon Jun  1 03:43:52 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 440.82       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   61C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                       GPU Memory |
# ...

# %%
# !pip2 install tensorflow-gpu==1.15
# !pip2 install scipy==1.1.0
# !pip2 install opencv-python
# Out:
# ...
#      |████████████████████████████████| 411.5MB 35kB/s
# ...
#      |████████████████████████████████| 3.8MB 51.5MB/s
# ...
#      |████████████████████████████████| 512kB 61.4MB/s
# ...
# ERROR: tensorflow 2.1.0 has requirement tensorboard<2.2.0,>=2.1.0, but you'll have tensorboard 1.15.0 which is incompatible.
# ERROR: tensorflow 2.1.0 has requirement tensorflow-estimator<2.2.0,>=2.1.0rc0, but you'll have tensorflow-estimator 1.15.1 which is incompatible.
# ...
#   Found existing installation: tensorboard 2.1.0
#     Uninstalling tensorboard-2.1.0:
#       Successfully uninstalled tensorboard-2.1.0
#   Found existing installation: tensorflow-estimator 1.15.0
#     Uninstalling tensorflow-estimator-1.15.0:
#       Successfully uninstalled tensorflow-estimator-1.15.0
# ...
#      |████████████████████████████████| 30.8MB 100kB/s
# ...
# ERROR: tensorflow 2.1.0 has requirement scipy==1.2.2; python_version < "3", but you'll have scipy 1.1.0 which is incompatible.
# ...

# %%
# !python2 ./augmentation.py --data_path=../data/test/
# Out:
# 0b607c1a-e6aaa838.jpg
# 0b607c1a-e6aaa838.jpg
# 0b73f056-a266e10d.jpg
# 0b9e72e1-2855d45f.jpg
# 0c8a2c79-0194bc27.jpg
# ((720, 1280, 3), (1280, 720))
# ((720, 1280, 3), (1280, 720))
# ((720, 1280, 3), (1280, 720))
# ((720, 1280, 3), (1280, 720))

# %%
# !python2 generate_tfrecords.py --image_dir=../data/test/Images/ --label_dir=../data/test/Labels/ --tfr_dir=./tf_records
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0601 03:58:32.767260 139624104789888 module_wrapper.py:139] From generate_tfrecords.py:263: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0601 03:58:32.767790 139624104789888 module_wrapper.py:139] From generate_tfrecords.py:251: The name tf.gfile.IsDirectory is deprecated. Please use tf.io.gfile.isdir instead.
#
# ['0c8a2c79-0194bc27.jpg', '0c8a2c79-0194bc27.jpg']
# ['0b607c1a-e6aaa838.jpg', '0b607c1a-e6aaa838.jpg']
# ['0b9e72e1-2855d45f.jpg', '0b9e72e1-2855d45f.jpg']
# ['0b73f056-a266e10d.jpg', '0b73f056-a266e10d.jpg']
# ['zzzz_0c8a2c79-0194bc27.jpg', 'zzzz_0c8a2c79-0194bc27.jpg']
# ['zzzz_0b607c1a-e6aaa838.jpg', 'zzzz_0b607c1a-e6aaa838.jpg']
# ['zfff_0c8a2c79-0194bc27.jpg', 'zfff_0c8a2c79-0194bc27.jpg']
# ['zfff_0b607c1a-e6aaa838.jpg', 'zfff_0b607c1a-e6aaa838.jpg']
# ['zzzz_0b9e72e1-2855d45f.jpg', 'zzzz_0b9e72e1-2855d45f.jpg']
# ['c1zzz_0c8a2c79-0194bc27.jpg', 'c1zzz_0c8a2c79-0194bc27.jpg']
# ...

# %%
# !python2 train.py --tf_record_pattren=./tf_records/train-?????-of-00002 --resnet_50_checkpoint_path=../../models/res50/resnet_v2_50.ckpt --batch_size=16 --train_outs=./train_outs
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0601 04:01:54.426908 140642753607552 module_wrapper.py:139] From /content/drive/My Drive/Lane_Detection/Lane-Detection/resnet.py:10: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0601 04:01:54.894243 140642753607552 module_wrapper.py:139] From train.py:173: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0601 04:01:54.894701 140642753607552 deprecation.py:323] From /content/drive/My Drive/Lane_Detection/Lane-Detection/TfRead.py:123: __init__ (from tensorflow.python.ops.io_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Queue-based input pipelines have been replaced by `tf.data`. Use `tf.data.TFRecordDataset`.
# ...

# %%
# !python2 test.py --test_dir=./test_images --checkpoint=../..//models/model-185003 --out_dir=./test_out
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0601 03:48:48.962389 140434275473280 module_wrapper.py:139] From /content/drive/My Drive/Lane_Detection/Lane-Detection/resnet.py:10: The name tf.GraphKeys is deprecated. Please use tf.compat.v1.GraphKeys instead.
#
# W0601 03:48:48.980654 140434275473280 module_wrapper.py:139] From test.py:151: The name tf.app.run is deprecated. Please use tf.compat.v1.app.run instead.
#
# W0601 03:48:48.981164 140434275473280 module_wrapper.py:139] From test.py:113: The name tf.placeholder is deprecated. Please use tf.compat.v1.placeholder instead.
#
# output directory already exists
# W0601 03:48:48.982645 140434275473280 module_wrapper.py:139] From test.py:116: The name tf.ConfigProto is deprecated. Please use tf.compat.v1.ConfigProto instead.
#
# W0601 03:48:48.982861 140434275473280 module_wrapper.py:139] From test.py:119: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
#
# ...
